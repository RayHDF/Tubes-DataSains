# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('RTA.csv')

# %%
df
# Out:
#       Age_band_of_driver Sex_of_driver   Educational_level  \
# 0                  18-30          Male   Above high school
# 1                  31-50          Male  Junior high school
# 2                  18-30          Male  Junior high school
# 3                  18-30          Male  Junior high school
# 4                  18-30          Male  Junior high school
# ...                  ...           ...                 ...
# 12311              31-50          Male             Unknown
# 12312            Unknown          Male   Elementary school
# 12313            Over 51          Male  Junior high school
# 12314              18-30        Female  Junior high school
# 12315              18-30          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience  \
# 0                    Employee              1-2yr
# 1                    Employee         Above 10yr
# 2                    Employee              1-2yr
# 3                    Employee             5-10yr
# ...

# %%
# Replace Unknown with Male or Female
import random

def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Male', 'Female'])
    else:
        return value

df['Sex_of_driver'] = df['Sex_of_driver'].apply(replace_unknown)

# %%
# Binary Encoder
df['Sex_of_driver'] = df['Sex_of_driver'].replace({'Male': 0, 'Female': 1})
# Out:
# C:\Users\Axioo Pongo\AppData\Local\Temp\ipykernel_8928\4130199564.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex_of_driver'] = df['Sex_of_driver'].replace({'Male': 0, 'Female': 1})

# %%
# Value counts 'Age_band_of_driver'
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %%
# Replace 'Unknown' with random values

def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['18-30', '31-50', 'Over 51', 'Under 18'])
    else:
        return value

df['Age_band_of_driver'] = df['Age_band_of_driver'].apply(replace_unknown)

# %%
# Value counts 'Age_band_of_driver'
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4687
# 31-50       4447
# Over 51     1955
# Under 18    1227
# Name: count, dtype: int64

# %%
# Label Encoder
df['Age_band_of_driver'] = df['Age_band_of_driver'].replace({'Under 18': 0, '18-30': 1, '31-50': 2, 'Over 51': 3})
# Out:
# C:\Users\Axioo Pongo\AppData\Local\Temp\ipykernel_8928\3512517941.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Age_band_of_driver'] = df['Age_band_of_driver'].replace({'Under 18': 0, '18-30': 1, '31-50': 2, 'Over 51': 3})

# %%
df['Age_band_of_driver'].value_counts()
# Out:
# Age_band_of_driver
# 1    4687
# 2    4447
# 3    1955
# 0    1227
# Name: count, dtype: int64

# %%
# Value counts Educational_level
df['Educational_level'].value_counts()
# Out:
# Educational_level
# Junior high school    7619
# Elementary school     2163
# High school           1110
# Unknown                841
# Above high school      362
# Writing & reading      176
# Illiterate              45
# Name: count, dtype: int64

# %%
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Junior high school', 'Elementary school', 'High school', 'Above high school', 'Writing & reading', 'Illiterate'])
    else:
        return value

df['Educational_level'] = df['Educational_level'].apply(replace_unknown)

# %%
# Value Counts
df['Educational_level'].value_counts()
# Out:
# Educational_level
# Junior high school    7779
# Elementary school     2300
# High school           1245
# Above high school      506
# Writing & reading      302
# Illiterate             184
# Name: count, dtype: int64

# %%
# Label Encoder
df['Educational_level'] = df['Educational_level'].replace({'Illiterate': 0, 'Elementary school': 1, 'Junior high school': 2, 'High school': 3, 'Above high school': 4, 'Writing & reading': 5})
# Out:
# C:\Users\Axioo Pongo\AppData\Local\Temp\ipykernel_8928\913438503.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Educational_level'] = df['Educational_level'].replace({'Illiterate': 0, 'Elementary school': 1, 'Junior high school': 2, 'High school': 3, 'Above high school': 4, 'Writing & reading': 5})

# %%
# Value Counts
df['Educational_level'].value_counts()
# Out:
# Educational_level
# 2    7779
# 1    2300
# 3    1245
# 4     506
# 5     302
# 0     184
# Name: count, dtype: int64

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#       Vehicle_driver_relation Driving_experience  \
# 0                    Employee              1-2yr
# 1                    Employee         Above 10yr
# 2                    Employee              1-2yr
# ...

# %%
# Drop column 'Vehicle_driver_relation'
df = df.drop('Vehicle_driver_relation', axis=1)

# %%
df['Driving_experience'].value_counts()
# Out:
# Driving_experience
# 5-10yr        3363
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# Unknown        829
# No Licence     118
# unknown         33
# Name: count, dtype: int64

# %%
def replace_unknown(value):
    if value == 'Unknown' or value == 'unknown':
        return random.choice(['5-10yr', '2-5yr', 'Above 10yr', '1-2yr', 'Below 1yr', 'No Licence'])
    else:
        return value

df['Driving_experience'] = df['Driving_experience'].apply(replace_unknown)

# %%
# Value Counts
df['Driving_experience'].value_counts()
# Out:
# Driving_experience
# 5-10yr        3522
# 2-5yr         2744
# Above 10yr    2420
# 1-2yr         1904
# Below 1yr     1472
# No Licence     254
# Name: count, dtype: int64

# %%
# Encoding
df['Driving_experience'] = df['Driving_experience'].replace({'No Licence': 0, 'Below 1yr': 1, '1-2yr': 2, '2-5yr': 3, '5-10yr': 4, 'Above 10yr': 5})
# Out:
# C:\Users\Axioo Pongo\AppData\Local\Temp\ipykernel_8928\4285662832.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Driving_experience'] = df['Driving_experience'].replace({'No Licence': 0, 'Below 1yr': 1, '1-2yr': 2, '2-5yr': 3, '5-10yr': 4, 'Above 10yr': 5})

# %%
df['Lanes_or_Medians'].value_counts()
# Out:
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4411
# Undivided Two way                                   3796
# other                                               1660
# Double carriageway (median)                         1020
# One way                                              845
# Unknown                                              442
# Two-way (divided with solid lines road marking)      142
# Name: count, dtype: int64

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#        Driving_experience                                  Lanes_or_Medians  \
# 0                       2                                           Unknown
# 1                       5                                 Undivided Two way
# ...

# %% [markdown]
# ### To Be OneHotEncoded
# ###### Lanes_or_Medians
# ###### Types_of_Junction
# ###### Road_surface_type
# ###### Weather_conditions

# %%
# Value counts Weather_conditions
df['Light_conditions'].value_counts()
# Out:
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: count, dtype: int64

# %%
df['Light_conditions'] = df['Light_conditions'].replace({'Darkness - no lighting': 0, "Darkness - lights unlit": 0, 'Darkness - lights lit': 1, 'Daylight': 2})
# Out:
# C:\Users\Axioo Pongo\AppData\Local\Temp\ipykernel_8928\695137973.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Light_conditions'] = df['Light_conditions'].replace({'Darkness - no lighting': 0, "Darkness - lights unlit": 0, 'Darkness - lights lit': 1, 'Daylight': 2})

# %%
# Value counts Weather_conditions
df['Light_conditions'].value_counts()
# Out:
# Light_conditions
# 2    8798
# 1    3286
# 0     232
# Name: count, dtype: int64

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#        Driving_experience                                  Lanes_or_Medians  \
# 0                       2                                           Unknown
# 1                       5                                 Undivided Two way
# ...

# %%
df['Lanes_or_Medians'].value_counts()
# Out:
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4411
# Undivided Two way                                   3796
# other                                               1660
# Double carriageway (median)                         1020
# One way                                              845
# Unknown                                              442
# Two-way (divided with solid lines road marking)      142
# Name: count, dtype: int64

# %%
# Replace Unknown with random values
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Two-way (divided with broken lines road marking)', 'Undivided Two way', 'Double carriageway (median)', 'One way', 'Two-way (divided with solid lines road marking)'])
    else:
        return value

df['Lanes_or_Medians'] = df['Lanes_or_Medians'].apply(replace_unknown)

# %%
df['Lanes_or_Medians'].value_counts()
# Out:
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4506
# Undivided Two way                                   3881
# other                                               1660
# Double carriageway (median)                         1111
# One way                                              937
# Two-way (divided with solid lines road marking)      221
# Name: count, dtype: int64

# %%
df['Types_of_Junction'].value_counts()
# Out:
# Types_of_Junction
# Y Shape        4543
# No junction    3837
# Crossing       2177
# Unknown        1078
# Other           445
# O Shape         164
# T Shape          60
# X Shape          12
# Name: count, dtype: int64

# %%
# Replace Unknown with random values
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Y Shape', 'No junction', 'Crossing', 'O Shape', 'T Shape', 'X Shape'])
    else:
        return value
    
df['Types_of_Junction'] = df['Types_of_Junction'].apply(replace_unknown)

# %%
df['Types_of_Junction'].value_counts()
# Out:
# Types_of_Junction
# Y Shape        4727
# No junction    4016
# Crossing       2346
# Other           445
# O Shape         351
# T Shape         251
# X Shape         180
# Name: count, dtype: int64

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#        Driving_experience                                  Lanes_or_Medians  \
# 0                       2                                           One way
# 1                       5                                 Undivided Two way
# ...

# %%
df['Road_surface_type'].value_counts()
# Out:
# Road_surface_type
# Asphalt roads                       11296
# Earth roads                           358
# Gravel roads                          242
# Unknown                               172
# Other                                 167
# Asphalt roads with some distress       81
# Name: count, dtype: int64

# %%
# Replace Unknown with random values
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Asphalt roads', 'Earth roads', 'Gravel roads', 'Asphalt roads with some distress'])
    else:
        return value
    
df['Road_surface_type'] = df['Road_surface_type'].apply(replace_unknown)

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#        Driving_experience                                  Lanes_or_Medians  \
# 0                       2                                           One way
# 1                       5                                 Undivided Two way
# ...

# %%
df['Type_of_collision'].value_counts()
# Out:
# Type_of_collision
# Vehicle with vehicle collision             8774
# Collision with roadside objects            1786
# Collision with pedestrians                  896
# Rollover                                    397
# Collision with animals                      171
# Unknown                                     169
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# With Train                                    9
# Name: count, dtype: int64

# %%
# Replace Unknown with random values
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Vehicle with vehicle collision', 'Collision with roadside objects', 'Collision with pedestrians', 'Rollover', 'Collision with animals', 'Collision with roadside-parked vehicles', 'Fall from vehicles', 'With Train' ])
    else:
        return value
    
df['Type_of_collision'] = df['Type_of_collision'].apply(replace_unknown)

# %%
# Value counts 'Vehicle_movement'
df['Vehicle_movement'].value_counts()
# Out:
# Vehicle_movement
# Going straight         8158
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Unknown                 396
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: count, dtype: int64

# %%
# Replace Unknown with random values
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['Going straight', 'Moving Backward', 'Reversing', 'Turnover', 'Getting off', 'Entering a junction', 'Overtaking', 'Waiting to go', 'U-Turn', 'Stopping', 'Parked'])
    else:
        return value
    
df['Vehicle_movement'] = df['Vehicle_movement'].apply(replace_unknown)

# %%
df['Vehicle_movement'].value_counts()
# Out:
# Vehicle_movement
# Going straight         8185
# Moving Backward        1017
# Other                   937
# Reversing               604
# Turnover                528
# Getting off             377
# Entering a junction     232
# Overtaking              131
# Stopping                100
# U-Turn                   89
# Waiting to go            72
# Parked                   44
# Name: count, dtype: int64

# %%
# Drop column 'Pedestrian_movement'
df = df.drop('Pedestrian_movement', axis=1)

# %%
df['Cause_of_accident'].value_counts()
# Out:
# Cause_of_accident
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# No priority to pedestrian                721
# Other                                    456
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Turnover                                  78
# Overspeed                                 61
# Overloading                               59
# Drunk driving                             27
# Unknown                                   25
# Improper parking                          25
# Name: count, dtype: int64

# %%
# Replace Unknown with random values
def replace_unknown(value):
    if value == 'Unknown':
        return random.choice(['No distancing', 'Changing lane to the right', 'Changing lane to the left', 'Driving carelessly', 'No priority to vehicle', 'Moving Backward', 
                              'No priority to pedestrian', 'Overtaking', 'Driving under the influence of drugs', 'Driving to the left', 'Getting off the vehicle improperly',
                              'Driving at high speed', 'Overturning', 'Turnover', 'Overspeed', 'Overloading', 'Drunk driving' ,'Improper parking'])
    else:
        return value
    
df['Cause_of_accident'] = df['Cause_of_accident'].apply(replace_unknown)

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#        Driving_experience                                  Lanes_or_Medians  \
# 0                       2                                           One way
# 1                       5                                 Undivided Two way
# ...

# %%
# Apply One Hot Encoding to 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 'Type_of_collision', 'Vehicle_movement', 'Cause_of_accident'
df = pd.get_dummies(df, columns=['Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 'Type_of_collision', 'Vehicle_movement', 'Cause_of_accident'])

# %%
df = pd.get_dummies(df, columns=['Weather_conditions'])

# %%
df
# Out:
#        Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0                       1              0                  4
# 1                       2              0                  2
# 2                       1              0                  2
# 3                       1              0                  2
# 4                       1              0                  2
# ...                   ...            ...                ...
# 12311                   2              0                  5
# 12312                   2              0                  1
# 12313                   3              0                  2
# 12314                   1              1                  2
# 12315                   1              0                  2
#
#        Driving_experience  Light_conditions  Accident_severity  \
# 0                       2                 2                  2
# 1                       5                 2                  2
# ...

# %%
# Export df to csv
df.to_csv('RTA_cleaned.csv', index=False)
